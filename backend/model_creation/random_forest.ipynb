# %%
import sys
sys.path.append('/usr/local/lib/python3.9/site-packages/')
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
import pandas as pd

# %%
def split(X, y, test_size, val_size):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=1)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=val_size/(1-test_size), random_state=1)

    return X_train, y_train, X_val, y_val, X_test, y_test

df = pd.read_csv('cleaned_extracted_data.csv')
df = df.drop('Unnamed: 0', axis=1)
X = df.drop('shares', axis=1)
y = df['shares']
X_train, y_train, X_val, y_val, X_test, y_test = split(X, y, 0.1, 0.3)

# %%
# %run evaluate_model.ipynb

# %%
def eval(model):
    print('Validation')
    y_pred = model.predict(X_val)
    evaluate_model(y_val, y_pred)

    print('\nTraining')
    y_pred = model.predict(X_train)
    evaluate_model(y_train, y_pred)

# %%
df.shape
# Out:
# (10600, 31)

# %%
rf = RandomForestRegressor(n_estimators=10, random_state=42, verbose=2)
rf.fit(X_train, y_train)
rf
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.2s remaining:    0.0s
# building tree 1 of 10
# building tree 2 of 10
# building tree 3 of 10
# building tree 4 of 10
# building tree 5 of 10
# building tree 6 of 10
# building tree 7 of 10
# building tree 8 of 10
# building tree 9 of 10
# building tree 10 of 10
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    1.9s finished
# RandomForestRegressor(n_estimators=10, random_state=42, verbose=2)

# %%
eval(rf)
# Out:
# Validation
# r2 score: -1.5451112767471504
# mean absolute error: 0.2576210466634515
# mean squared error: 0.7209378869369262
#
# Training
# r2 score: 0.7746484375381053
# mean absolute error: 0.09907416339314122
# mean squared error: 0.2565173256861101
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s finished

# %%
from sklearn.linear_model import LinearRegression, SGDRegressor

# %%
lin_reg = LinearRegression().fit(X_train, y_train)

# %%
eval(lin_reg)
# Out:
# Validation
# r2 score: -0.00014398287386940822
# mean absolute error: 0.20500899663375566
# mean squared error: 0.2833045832743769
#
# Training
# r2 score: 0.003012208968473873
# mean absolute error: 0.21387405950205884
# mean squared error: 1.1348696192881023

# %%
sgd = SGDRegressor().fit(X_train, y_train)
eval(sgd)
# Out:
# Validation
# r2 score: -0.043507306933599166
# mean absolute error: 0.23586912001554985
# mean squared error: 0.29558784314745334
#
# Training
# r2 score: -0.008237604267936627
# mean absolute error: 0.243842782919402
# mean squared error: 1.1476752638301062
