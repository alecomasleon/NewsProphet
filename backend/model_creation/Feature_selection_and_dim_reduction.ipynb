# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %run preprocess.ipynb
X, y = get_raw_data()
columns = [x.strip() for x in X.columns]
X.columns = columns
X, y = filter_features(X, y, ['n_tokens_title', 'n_tokens_content', 'n_unique_tokens',
   'n_non_stop_words', 'n_non_stop_unique_tokens', 'num_hrefs', 'num_imgs',
   'num_videos', 'average_token_length', 'weekday_is_monday',
   'weekday_is_tuesday', 'weekday_is_wednesday', 'weekday_is_thursday',
   'weekday_is_friday', 'weekday_is_saturday', 'weekday_is_sunday',
   'is_weekend', 'global_subjectivity', 'global_sentiment_polarity',
   'global_rate_positive_words', 'global_rate_negative_words',
   'rate_positive_words', 'rate_negative_words', 'avg_positive_polarity',
   'max_positive_polarity', 'avg_negative_polarity',
   'min_negative_polarity', 'title_subjectivity',
   'title_sentiment_polarity', 'abs_title_sentiment_polarity', "LDA_00", "LDA_01", "LDA_02", "LDA_03", "LDA_04"])
# Out:
# colums: Index(['n_tokens_title', 'n_tokens_content', 'n_unique_tokens',
#        'n_non_stop_words', 'n_non_stop_unique_tokens', 'num_hrefs',
#        'num_self_hrefs', 'num_imgs', 'num_videos', 'average_token_length',
#        'num_keywords', 'data_channel_is_lifestyle',
#        'data_channel_is_entertainment', 'data_channel_is_bus',
#        'data_channel_is_socmed', 'data_channel_is_tech',
#        'data_channel_is_world', 'kw_min_min', 'kw_max_min', 'kw_avg_min',
#        'kw_min_max', 'kw_max_max', 'kw_avg_max', 'kw_min_avg', 'kw_max_avg',
#        'kw_avg_avg', 'self_reference_min_shares', 'self_reference_max_shares',
#        'self_reference_avg_sharess', 'weekday_is_monday', 'weekday_is_tuesday',
#        'weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday',
#        'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'LDA_00',
#        'LDA_01', 'LDA_02', 'LDA_03', 'LDA_04', 'global_subjectivity',
# ...

# %%
#combine X and y
data = pd.concat([X, y], axis=1)
print(data.head())
print(data.shape)
# Out:
#    n_tokens_title  n_tokens_content  n_unique_tokens  n_non_stop_words  \
# 0            12.0             219.0         0.663594               1.0
# 1             9.0             255.0         0.604743               1.0
# 2             9.0             211.0         0.575130               1.0
# 3             9.0             531.0         0.503788               1.0
# 4            13.0            1072.0         0.415646               1.0
#
#    n_non_stop_unique_tokens  num_hrefs  num_imgs  num_videos  \
# 0                  0.815385        4.0       1.0         0.0
# 1                  0.791946        3.0       1.0         0.0
# 2                  0.663866        3.0       1.0         0.0
# 3                  0.665635        9.0       1.0         0.0
# 4                  0.540890       19.0      20.0         0.0
#
#    average_token_length  weekday_is_monday  ...  min_negative_polarity  \
# 0              4.680365                1.0  ...                 -0.600
# ...

# %%
#correlation matrix
# first 10 columns plus the target variable
cols = [x for x in X.columns[:10]]
cols.append(' shares')
print(cols)
cm = np.corrcoef(data[cols].values.T)
sns.set(font_scale=1.5)
plt.figure(figsize=(10,10))
hm = sns.heatmap(cm,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.2f',
                 annot_kws={'size': 12},
                 cmap='coolwarm',
                 yticklabels=cols,
                 xticklabels=cols)
plt.title('Correlation matrix showing correlation coefficients', size = 18)
plt.tight_layout()
plt.show()
# Out:
# ['n_tokens_title', 'n_tokens_content', 'n_unique_tokens', 'n_non_stop_words', 'n_non_stop_unique_tokens', 'num_hrefs', 'num_imgs', 'num_videos', 'average_token_length', 'weekday_is_monday', ' shares']

# %%
# next 10 columns plus the target variable
cols = [x for x in X.columns[11:21]]
cols.append(' shares')
print(cols)
cm = np.corrcoef(data[cols].values.T)
sns.set(font_scale=1.5)
plt.figure(figsize=(10,10))
hm = sns.heatmap(cm,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.2f',
                 annot_kws={'size': 12},
                 cmap='coolwarm',
                 yticklabels=cols,
                 xticklabels=cols)
plt.title('Correlation matrix showing correlation coefficients', size = 18)
plt.tight_layout()
plt.show()
# Out:
# ['weekday_is_wednesday', 'weekday_is_thursday', 'weekday_is_friday', 'weekday_is_saturday', 'weekday_is_sunday', 'is_weekend', 'global_subjectivity', 'global_sentiment_polarity', 'global_rate_positive_words', 'global_rate_negative_words', ' shares']

# %%
# next 10 columns plus the target variable
cols = [x for x in X.columns[22:32]]
cols.append(' shares')
print(cols)
cm = np.corrcoef(data[cols].values.T)
sns.set(font_scale=1.5)
plt.figure(figsize=(10,10))
hm = sns.heatmap(cm,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.2f',
                 annot_kws={'size': 12},
                 cmap='coolwarm',
                 yticklabels=cols,
                 xticklabels=cols)
plt.title('Correlation matrix showing correlation coefficients', size = 18)
plt.tight_layout()
plt.show()
# Out:
# ['rate_negative_words', 'avg_positive_polarity', 'max_positive_polarity', 'avg_negative_polarity', 'min_negative_polarity', 'title_subjectivity', 'title_sentiment_polarity', 'abs_title_sentiment_polarity', 'LDA_00', 'LDA_01', ' shares']

# %%
# last columns plus the target variable
cols = [x for x in X.columns[32:]]
cols.append(' shares')
print(cols)
cm = np.corrcoef(data[cols].values.T)
sns.set(font_scale=1.5)
plt.figure(figsize=(10,10))
hm = sns.heatmap(cm,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.2f',
                 annot_kws={'size': 12},
                 cmap='coolwarm',
                 yticklabels=cols,
                 xticklabels=cols)
plt.title('Correlation matrix showing correlation coefficients', size = 18)
plt.tight_layout()
plt.show()
# Out:
# ['LDA_02', 'LDA_03', 'LDA_04', ' shares']
